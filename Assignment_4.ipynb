# %%
Question 1

Empty list

# %%
#Question 2
spam = [2, 4, 6, 8, 10]

spam.insert(2,'hello')
print(spam)
# Out:
# [2, 4, 'hello', 6, 8, 10]

# %% [markdown]
# Question 3,4,5
#
# d
# d
# ['a','b']

# %%
spam = [2, 4, 6, 8, 10]
spam[1:0]
spam[:2]
# Out:
# [2, 4]

# %%
#Question 6,7,8

bacon = [3.14,'cat',11,'cat',True]
bacon.index('cat')
bacon.append(99)
print(bacon)
bacon.remove('cat')
print(bacon)
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]
# [3.14, 11, 'cat', True, 99]

# %%
#Question 9
list1= [2,3,4]
list2= [5,6,7]
newlist = list1*3 + list2*3 // Cancatenation and replication

print(newlist)
# Out:
# [2, 3, 4, 2, 3, 4, 2, 3, 4, 5, 6, 7, 5, 6, 7, 5, 6, 7]

# %% [markdown]
# Question 10
# append() will append the element at the last position
# insert() will insert element at any index

# %%
#Question 11
list = [1,2,3,5,6,7,'shubham']
list.remove(2)
list.pop(-2)
print(list)
# Out:
# [1, 3, 5, 6, 'shubham']

# %% [markdown]
# Question 12
# List values and string values are identical because both are collection of items and character respectively and are characterized by indexes. Differences between is Lists are mutable and strings are immuntable.

# %% [markdown]
# Question 13
#
# Lists are mutable whose values can be changed and using [] where tuples are immutable whose values can not be changed and using().

# %%
#Question 14
tuple = (42,)
type(tuple)
# Out:
# tuple

# %%
#Question 15
list2 = [1,2,3,4,5,6]
tuple2 = (7,8,9,10)
list1 = tuple(list2)
tuple1 = list(tuple2)

print(list1)
print(tuple1)

# %% [markdown]
# Question 16
#
#
# They contain references to list values.

# %% [markdown]
# Question 17
#
# The copy.copy() function will do a shallow copy of a list, while the copy.deepcopy() function will do a deep copy of a list. That is, only copy.deepcopy() will duplicate any lists inside the list.
